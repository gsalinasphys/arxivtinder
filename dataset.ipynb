# %%
# Filtering arxiv dataset
import pandas as pd
from filter_arxiv_file import filter_arxiv_file

# %%
filename = 'static/arxiv-metadata-oai-snapshot.json'

# %%
filter_arxiv_file(filename, 'static/arxiv-metadata-oai-snapshot_hepthph2.json', ['hep-th', 'hep-ph'])
# Out:
# 2091it [01:40, 20.90it/s]

# %%
arxiv_hepthph = pd.read_json('static/arxiv-metadata-oai-snapshot_hepthph.json', lines=True)

# %%
arxiv_hepthph.head()
# Out:
#          id           submitter  \
# 0  704.0001      Pavel Nadolsky
# 1  704.0015     Christian Stahn
# 2  704.0016             Li Tong
# 3  704.0018  Andreas Gustavsson
# 4  704.0029        Weizhen Deng
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                                    Christian Stahn
# 2  Chao-Hsi Chang, Tong Li, Xue-Qian Li and Yu-Mi...
# 3                                 Andreas Gustavsson
# 4          Zhan Shu, Xiao-Lin Chen and Wei-Zhen Deng
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1  Fermionic superstring loop amplitudes in the p...
# 2                 Lifetime of doubly charmed baryons
# 3    In quest of a generalized Callias index theorem
# 4  Understanding the Flavor Symmetry Breaking and...
#
#                                             comments  \
# 0            37 pages, 15 figures; published version
# ...

# %%
filter_arxiv_file(filename, 'static/arxiv-metadata-oai-snapshot_from20.json', None, 2020, 2023)
# Out:
# 2091it [01:15, 27.60it/s]

# %%
arxiv_from20 = pd.read_json('static/arxiv-metadata-oai-snapshot_from20.json', lines=True)

# %%
arxiv_from20.head()
# Out:
#          id          submitter  \
# 0  704.0033    Maxim A. Yurkin
# 1  704.0038    Maxim A. Yurkin
# 2  704.0275  George M. Bergman
# 3  704.0479   Thomas Geisser H
# 4  704.0752      Davoud Kamani
#
#                                              authors  \
# 0  Maxim A. Yurkin, Valeri P. Maltsev, Alfons G. ...
# 1                Maxim A. Yurkin, Alfons G. Hoekstra
# 2                   George M. Bergman (U.C.Berkeley)
# 3                                          T.Geisser
# 4                                      Davoud Kamani
#
#                                                title  \
# 0  Convergence of the discrete dipole approximati...
# 1  The discrete dipole approximation: an overview...
# 2                     Mapping radii of metric spaces
# 3               The affine part of the Picard scheme
# 4  Actions for the Bosonic String with the Curved...
#
#                                             comments  \
# 0  23 pages, 5 figures; added several corrections...
# ...

# %%
filter_arxiv_file(filename, 'static/arxiv-metadata-oai-snapshot_hepthph_from22.json', ['hep-th', 'hep-ph'], 2022)
# Out:
# 2091it [01:08, 30.67it/s]

# %%
arxiv_small = pd.read_json('static/arxiv-metadata-oai-snapshot_hepthph_from22.json', lines=True)

# %%
arxiv_small.head()
# Out:
#          id                submitter  \
# 0  705.3841  Michael Andreas Schmidt
# 1  706.4165      Dmitry Zhuridov Dr.
# 2  710.2975            Vakhid Gani A
# 3  801.0287          Alan Kostelecky
# 4  801.2512      Dmitry Zhuridov Dr.
#
#                                              authors  \
# 0                            Michael Andreas Schmidt
# 1                A. Ali, A.V. Borisov, D.V. Zhuridov
# 2  V. A. Gani, N. B. Konyukhova, S. V. Kurochkin,...
# 3                   Alan Kostelecky and Neil Russell
# 4  A. Ali (DESY, Hamburg), A.V. Borisov and D.V. ...
#
#                                                title  \
# 0  Renormalization Group Evolution in the type I ...
# 1  Probing new physics in the Neutrinoless double...
# 2  Study of Stability of a Charged Topological So...
# 3          Data Tables for Lorentz and CPT Violation
# 4  Electron angular correlation in neutrinoless d...
#
#                                             comments  \
# ...

# %%
arxiv_import = arxiv_small[['id', 'title', 'categories', 'abstract']]

# %%
arxiv_import.head()
# Out:
#          id                                              title  \
# 0  705.3841  Renormalization Group Evolution in the type I ...
# 1  706.4165  Probing new physics in the Neutrinoless double...
# 2  710.2975  Study of Stability of a Charged Topological So...
# 3  801.0287          Data Tables for Lorentz and CPT Violation
# 4  801.2512  Electron angular correlation in neutrinoless d...
#
#                             categories  \
# 0                               hep-ph
# 1                hep-ph hep-ex nucl-th
# 2               hep-th math-ph math.MP
# 3  hep-ph astro-ph gr-qc hep-ex hep-th
# 4                               hep-ph
#
#                                             abstract
# 0    We carefully analyze the renormalization gro...
# 1    The angular correlation of the electrons emi...
# 2    An analytical-numerical analysis of the sing...
# 3    This work tabulates measured and derived val...
# 4    The angular correlation of the electrons in ...

# %%
import json

with open('static/arxiv-small.json', "w") as f:
    f.writelines(
        json.dumps(d) + "\n" for d in arxiv_import.to_dict(orient="records")
    )
