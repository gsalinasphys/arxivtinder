# %%
# Filtering arxiv dataset
import pandas as pd
from pathlib import Path

from dataset_filter import arxiv_filter

# %%
# # Divide dataset into chunks
# chunk_size = 10_000
# batch_no = 1

# for chunk in pd.read_json('static/arxiv-metadata-oai-snapshot.json', lines=True, chunksize=chunk_size):
#     chunk.to_json('static/chunks/chunk'+str(batch_no)+'.json')
#     batch_no+=1

# %%
# Reading a chunk of data from file
achunk = pd.read_json('static/chunks/chunk1.json')

# %%
from_yr = 2012
by_category = ['hep-ph', 'hep-th']

# Filter papers starting from year 'from_yr' and categories in list 'by_category' for a single chunk
achunk_filter = achunk.loc[(achunk['update_date']>=str(from_yr)) & (achunk['categories'].isin(by_category))]

# %%
achunk_filter.head()
# Out:
#            id        submitter  \
# 368  704.0369   Tatsu Takeuchi
# 443  704.0444  Jacob Bourjaily
# 448  704.0449     Volker Braun
# 751  704.0752    Davoud Kamani
# 828  704.0829   Bang-Rong Zhou
#
#                                                authors  \
# 368  Minako Honda, Yee Kao, Naotoshi Okamura, Alexe...
# 443                                 Jacob L. Bourjaily
# 448  Volker Braun, Maximilian Kreuzer, Burt A. Ovru...
# 751                                      Davoud Kamani
# 828  Bang-Rong Zhou (Graduate School of Chinese Aca...
#
#                                                  title  \
# 368  The effect of Topcolor Assisted Technicolor, a...
# 443  Multiple Unfoldings of Orbifold Singularities:...
# 448  Worldsheet Instantons and Torsion Curves, Part...
# 751  Actions for the Bosonic String with the Curved...
# 828  Quark-Antiquark and Diquark Condensates in Vac...
#
#                                               comments  \
# 368  7 pages, latex, uses ws-procs9x6.cls; talk pre...
# 443                                4 pages, 2 figures.
# 448                                    59 pages, LaTeX
# 751  8 pages, Latex, no figure, Some minor changes ...
# 828  5 pages, revtex4, no figure, minor typos corre...
#
#                            journal-ref                              doi  \
# 368                               None       10.1142/9789812790750_0027
# 443                               None       10.1103/PhysRevD.79.046005
# 448                  JHEP0710:023,2007    10.1088/1126-6708/2007/10/023
# 751  Braz. J. Phys. 38, 268-271 (2008)  10.1590/S0103-97332008000200010
# 828  Commun.Theor. Phys. 47 (2007) 695       10.1088/0253-6102/47/4/027
#
#                                     report-no categories license  \
# 368  OCHA-PP-270, YITP-07-09, VPI-IPNAS-07-02     hep-ph    None
# 443                                      None     hep-th    None
# 448         UPR 1178-T, DISTA-2007, TUW-07-08     hep-th    None
# 751                                      None     hep-th    None
# 828                                      None     hep-th    None
#
#                                               abstract  \
# 368    New physics beyond the Standard Model can le...
# 443    Katz and Vafa showed how charged matter can ...
# 448    We apply mirror symmetry to the problem of c...
# 751    At first we introduce an action for the stri...
# 828    The effective potential analysis indicates t...
#
#                                               versions update_date  \
# 368  [{'version': 'v1', 'created': 'Tue, 3 Apr 2007...  2017-08-23
# 443  [{'version': 'v1', 'created': 'Tue, 3 Apr 2007...  2013-05-29
# 448  [{'version': 'v1', 'created': 'Tue, 3 Apr 2007...  2016-09-08
# 751  [{'version': 'v1', 'created': 'Thu, 5 Apr 2007...  2020-08-21
# 828  [{'version': 'v1', 'created': 'Fri, 6 Apr 2007...  2015-05-13
#
#                                         authors_parsed
# 368  [[Honda, Minako, ], [Kao, Yee, ], [Okamura, Na...
# 443                          [[Bourjaily, Jacob L., ]]
# 448  [[Braun, Volker, ], [Kreuzer, Maximilian, ], [...
# 751                               [[Kamani, Davoud, ]]
# 828  [[Zhou, Bang-Rong, , Graduate School of Chines...

# %%
directory = 'static/chunks/'
arxiv_from17 =  arxiv_filter(directory, (2017, 2022))

# %%
arxiv_from17.head()
# Out:
#                  id        submitter  \
# 1430000  2102.13511         Kevin Li
# 1430001  2102.13512    Erkki Kankare
# 1430002  2102.13513     Tom Kaufmann
# 1430003  2102.13514   Rahim Mammadli
# 1430004  2102.13515  V\'ictor Campos
#
#                                                    authors  \
# 1430000                                           Kevin Li
# 1430001  E. Kankare, A. Efstathiou, R. Kotak, E. C. Koo...
# 1430002                                       Tom Kaufmann
# 1430003  Rahim Mammadli, Marija Selakovic, Felix Wolf, ...
# 1430004  V\'ictor Campos, Pablo Sprechmann, Steven Hans...
#
#                                                      title  \
# 1430000  On the topological complexity of toral relativ...
# 1430001  Core-collapse supernova subtypes in luminous i...
# 1430002  Sharp Asymptotics for $q$-Norms of Random Vect...
# 1430003  Learning to Make Compiler Optimizations More E...
# 1430004  Beyond Fine-Tuning: Transferring Behavior in R...
#
#                                                   comments  \
# 1430000                          7 pages, comments welcome
# 1430001  25 pages, 21 figures, accepted for publication...
# 1430002  28 pages, Updated Version: Reworked the proof ...
# 1430003                                15 pages, 4 figures
# 1430004                                               None
#
#                                                journal-ref  \
# 1430000                                               None
# 1430001                                               None
# 1430002  Modern Stoch. Theory Appl. 8(2021), no. 2, 239...
# 1430003                                               None
# 1430004                                               None
#
#                                  doi report-no  \
# 1430000                         None      None
# 1430001  10.1051/0004-6361/202039240      None
# 1430002         10.15559/21-VMSTA182      None
# 1430003                         None      None
# 1430004                         None      None
#
#                                   categories  \
# 1430000                      math.AT math.GR
# 1430001  astro-ph.SR astro-ph.GA astro-ph.HE
# 1430002                              math.PR
# 1430003                          cs.PL cs.LG
# 1430004                  cs.LG cs.AI stat.ML
#
#                                                    license  \
# 1430000  http://arxiv.org/licenses/nonexclusive-distrib...
# 1430001  http://arxiv.org/licenses/nonexclusive-distrib...
# 1430002        http://creativecommons.org/licenses/by/4.0/
# 1430003  http://arxiv.org/licenses/nonexclusive-distrib...
# 1430004  http://creativecommons.org/licenses/by-nc-nd/4.0/
#
#                                                   abstract  \
# 1430000    We prove that the topological complexity $\m...
# 1430001    We present the discovery and follow-up obser...
# 1430002    Sharp large deviation results of Bahadur-Ran...
# 1430003    Because loops execute their body many times,...
# 1430004    Designing agents that acquire knowledge auto...
#
#                                                   versions update_date  \
# 1430000  [{'version': 'v1', 'created': 'Fri, 26 Feb 202...  2021-03-01
# 1430001  [{'version': 'v1', 'created': 'Fri, 26 Feb 202...  2021-06-02
# 1430002  [{'version': 'v1', 'created': 'Fri, 26 Feb 202...  2021-08-10
# 1430003  [{'version': 'v1', 'created': 'Wed, 24 Feb 202...  2021-03-01
# 1430004  [{'version': 'v1', 'created': 'Wed, 24 Feb 202...  2021-06-09
#
#                                             authors_parsed
# 1430000                                    [[Li, Kevin, ]]
# 1430001  [[Kankare, E., ], [Efstathiou, A., ], [Kotak, ...
# 1430002                                [[Kaufmann, Tom, ]]
# 1430003  [[Mammadli, Rahim, ], [Selakovic, Marija, ], [...
# 1430004  [[Campos, Víctor, ], [Sprechmann, Pablo, ], [H...

# %%
len(arxiv_from17)
# Out:
# 959827

# %%
arxiv_from17.to_json('static/arxiv-metadata-oai-snapshot_from17.json')

# %%
arxiv_hepthph =  arxiv_filter(directory, (2012, 2022), ['hep-ph', 'hep-th'])

# %%
len(arxiv_hepthph)
# Out:
# 56485

# %%
arxiv_hepthph.to_json('static/arxiv-metadata-oai-snapshot_hepthph.json')
